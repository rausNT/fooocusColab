# %% [markdown]
# <a href="https://colab.research.google.com/github/rausNT/fooocusColab/blob/main/fooocus_Photorealistic_building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/mashb1t/Fooocus.git
# %cd /content/Fooocus


# установка архитектурной модели - выбрать в сеттинге
# !pip install -q gdown
# !gdown --id 1WlBqT7CJPst_8nrhqmQ_EjOaRIfjnCEA -O /content/Fooocus/models/checkpoints/ArchitectureRealMix.safetensors

# 1. Установите необходимые библиотеки
# !pip install -q gdown
from google.colab import drive

# 2. Подключите Google Drive
drive.mount('/content/drive')

# 3. ID вашей папки с LoRA (из ссылки)
folder_id = "1Oa5kWnwgtsBQ2kYZ3ye1QBIPuVHDRHn4"

# 4. Создайте папку для LoRA
# !mkdir -p /content/Fooocus/models/loras

# 5. Скопируйте все файлы из папки Drive
import shutil

try:
    # Путь к папке в Google Drive
    drive_path = f"/content/drive/MyDrive/{folder_id}"

    # Копируем все файлы рекурсивно
    shutil.copytree(drive_path, "/content/Fooocus/models/loras", dirs_exist_ok=True)

    print("✅ Все LoRA успешно скопированы!")
    # !ls -lh /content/Fooocus/models/loras

except Exception as e:
    print(f"❌ Ошибка: {str(e)}")
    print("Альтернативный метод через gdown:")

    # Если не работает copytree, качаем через gdown
    # !gdown --folder https://drive.google.com/drive/folders/{folder_id} -O /content/Fooocus/models/loras
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 65.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 11120, done.
# remote: Total 11120 (delta 0), reused 0 (delta 0), pack-reused 11120 (from 1)
# Receiving objects: 100% (11120/11120), 57.46 MiB | 15.51 MiB/s, done.
# Resolving deltas: 100% (6389/6389), done.
# /content/Fooocus
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1WlBqT7CJPst_8nrhqmQ_EjOaRIfjnCEA
# ...

# %%
# !python entry_with_update.py --share --always-high-vram --preset realistic
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 100% 377M/377M [00:00<00:00, 459MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# ...
